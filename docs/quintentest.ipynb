# %% [markdown]
# # Cindy, Wylie, and Quinten's Visualization Project
#
# Thanks for visiting our website! We are excited to show off our visualizations of Bay Area EPC tracts
#
# ## Interactive Daytime Population Map
#
# The EPC tracts are outlined in red:
#
# [text](../visualizations/daytime_pop.html)
#
# ## Daytime vs Nighttime Population by Bay Area County
#
# ![alt text](../visualizations/day_night_county.png)
#
# ## EPC Net Change in Daily Population vs All Tracts
#
# ![alt text](../visualizations/netpopchange_overlaid_logscale.png)

# %%
from IPython.display import IFrame

# Point this to your saved Folium map
# Adjust height and width as needed for your Bay Area map
IFrame(src='./visualizations/daytime_pop.html', width='100%', height=600)
# Out:
#         <iframe
#             width="100%"
#             height="600"
#             src="./visualizations/daytime_pop.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
